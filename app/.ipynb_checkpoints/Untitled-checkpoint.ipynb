# %%
from IO import IO
# Out:
# /home/jupyter/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
import pandas as pd

# %%
a = IO()

# %%
a.load_data()

# %%
a._patients
# Out:
#                                     ID Gender      Birth      Death
# 0     0007613eee440aa3145f09e1dfd0865b      M 1968-07-01 2013-04-10
# 1     000ef5e1cc6b18c92c3da94886c205f2      M 1951-11-01        NaT
# 2     001561666d3f7af58205c452df1006a7      F 1950-09-01        NaT
# 3     001653b694bd769cca36d1181624f260      M 1966-06-01        NaT
# 4     001bb0fb0274b845fcf167f24548fa0b      F 1929-09-01 2013-04-29
# ...                                ...    ...        ...        ...
# 9980  ffe8f6a2b8b9b7a9da4a175e30534dc0      F 1933-05-01 2012-02-04
# 9981  fff2ecdf8a0234c105986a3b4a45ae5b      F 1932-11-01        NaT
# 9982  fff4368e1efbcb5223a980972093b0d9      M 1947-10-01 2010-08-09
# 9983  fffc746780c2e287bd0fac61d5528722      M 1939-06-01        NaT
# 9984  fffd2516e3115669a1b9319c813b62e0      M 1955-07-01        NaT
#
# [9985 rows x 4 columns]

# %%
a._records
# Out:
#                                 PatientID  SeqNo     InDate          Area  \
# 0        0007613eee440aa3145f09e1dfd0865b      0 1998-09-07  TaichungCity
# 1        0007613eee440aa3145f09e1dfd0865b      1 1999-01-14  TaichungCity
# 2        0007613eee440aa3145f09e1dfd0865b      2 1999-01-25  TaichungCity
# 3        0007613eee440aa3145f09e1dfd0865b      3 1999-01-27  TaichungCity
# 4        0007613eee440aa3145f09e1dfd0865b      4 1999-01-28  TaichungCity
# ...                                   ...    ...        ...           ...
# 4109097  a3e40da42bceda3fd5c7b9ea7e10dbb6      1 2013-09-14           NaN
# 4109098  a3e40da42bceda3fd5c7b9ea7e10dbb6      2 2013-12-10           NaN
# 4109099  a9f2ae6de2106c49cadf46aeeffb03d6      1 2013-10-15           NaN
# 4109100  4b577d2feb43ce56afc4f854b461b735      1 2013-11-25           NaN
# 4109101  23d4793aa20a375d5490fdc1b45b2a7e      1 2013-11-27           NaN
#
#          Type  ApplyDot  TotalDot                         ICD9CM HospSpecItem  \
# ...

# %%
df = a._records
df = df[df['Type']==2.0]

# %%
pd.merge(a._patients,df,left_on='ID',right_on='PatientID').iloc[150:200]
# Out:
#                                    ID Gender      Birth      Death  \
# 150  00ecf588b61e4afdc2c2913de253c900      F 1938-01-01        NaT
# 151  00ecf588b61e4afdc2c2913de253c900      F 1938-01-01        NaT
# 152  00ecf588b61e4afdc2c2913de253c900      F 1938-01-01        NaT
# 153  00ecf588b61e4afdc2c2913de253c900      F 1938-01-01        NaT
# 154  00ecf588b61e4afdc2c2913de253c900      F 1938-01-01        NaT
# 155  0103430ff3f022ea538c4161d0474d0c      M 1932-05-01        NaT
# 156  0103430ff3f022ea538c4161d0474d0c      M 1932-05-01        NaT
# 157  0103430ff3f022ea538c4161d0474d0c      M 1932-05-01        NaT
# 158  0103430ff3f022ea538c4161d0474d0c      M 1932-05-01        NaT
# 159  0103430ff3f022ea538c4161d0474d0c      M 1932-05-01        NaT
# 160  0103430ff3f022ea538c4161d0474d0c      M 1932-05-01        NaT
# 161  0103430ff3f022ea538c4161d0474d0c      M 1932-05-01        NaT
# 162  0104970c0db2c2b03b193438c09b3b8c      F 1925-12-01 2011-10-14
# ...

# %%
a.set_patient_by_id('015b8ac98a1019c00a3d16d2db53bb42')

# %%
a.get_quickly_death_model_point()
# Out:
# 0.89265126

# %%
a.get_patient_personal_data()
# Out:
# '{"0":{"id":"015b8ac98a1019c00a3d16d2db53bb42","gender":"M","birthdate":"06-01-1937"}}'
