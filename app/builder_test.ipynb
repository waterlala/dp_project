# %%
import json
import numpy as np
import pandas as pd
from patient import *

# %%
with open('./patient.json','r') as patient_reader:
    patinet_data = json.load(patient_reader)
with open('./record.json','r') as record_reader:
    record_data = json.load(record_reader)
with open('./inpatient.json','r') as inpatient_reader:
    inpatient_data = json.load(inpatient_reader)

# %%
patient_df = pd.DataFrame.from_dict(patinet_data , orient='index')
record_df = pd.DataFrame.from_dict(record_data , orient='index')
inpatient_df = pd.DataFrame.from_dict(inpatient_data , orient='index')

# %%
# Out:
#                                      ID  SeqNo               InDate  \
# 0      0007613eee440aa3145f09e1dfd0865b      0  1998-09-07 00:00:00
# 1      0007613eee440aa3145f09e1dfd0865b      1  1999-01-14 00:00:00
# 2      0007613eee440aa3145f09e1dfd0865b      2  1999-01-25 00:00:00
# 3      0007613eee440aa3145f09e1dfd0865b      3  1999-01-27 00:00:00
# 4      0007613eee440aa3145f09e1dfd0865b      4  1999-01-28 00:00:00
# ...                                 ...    ...                  ...
# 41666  06ab9e7c867adfb71cfa69adaaaf1108    321  2011-03-19 00:00:00
# 41667  06ab9e7c867adfb71cfa69adaaaf1108    322  2011-03-21 00:00:00
# 41668  06ab9e7c867adfb71cfa69adaaaf1108    323  2011-03-24 00:00:00
# 41669  06ab9e7c867adfb71cfa69adaaaf1108    324  2011-03-26 00:00:00
# 41670  06ab9e7c867adfb71cfa69adaaaf1108    326  2011-04-01 00:00:00
#
#                Area Type  ApplyDot  TotalDot           ICD9CM
# 0      TaichungCity    1    211151    230151  [410, 410, 413]
# 1      TaichungCity    1     14515     16128       [682, 785]
# 2      TaichungCity    0        50       325            [682]
# 3      TaichungCity    0        50       307            [682]
# 4      TaichungCity    0        50       686            [682]
# ...             ...  ...       ...       ...              ...
# 41666  YunlinCounty    0        90       483       [428, 290]
# 41667  YunlinCounty    0       100       894       [428, 290]
# 41668  YunlinCounty    0       100       359  [782, 428, 459]
# 41669  YunlinCounty    0       180       975  [427, 428, 414]
# 41670  YunlinCounty    1     86628     96253  [428, 486, 414]
#
# [41671 rows x 8 columns]
